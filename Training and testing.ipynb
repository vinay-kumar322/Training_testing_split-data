# %% [markdown]
# ## Training and testing Data

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\DELL\Downloads\car_mailege.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## scatter plot of "Mileage" & "Sell Price($)" & "Age(yrs)"

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])
plt.show()

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])
plt.figure(figsize = (3,4))
plt.show()

# %%
x=df[['Mileage','Age(yrs)']]
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 4     46000         4
# 18    87600         8
# 0     69000         6
# 10    83000         7
# 14    82450         7
# 5     59000         5
# 13    58780         4
# 2     57000         5
# 8     91000         8
# 19    52000         5
# 9     67000         6
# 3     22500         2
# 17    69000         5
# 11    79000         7

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 16    28000         2
# 6     52000         5
# 15    25400         3
# 1     35000         3
# 7     72000         6
# 12    59000         5

# %%
y_train
# Out:
# 4     31500
# 18    12800
# 0     18000
# 10    18700
# 14    19400
# 5     26750
# 13    27500
# 2     26100
# 8     12000
# 19    28200
# 9     22000
# 3     40000
# 17    19700
# 11    19500
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 16    35500
# 6     32000
# 15    35000
# 1     34000
# 7     19300
# 12    26000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 16    28000         2
# 6     52000         5
# 15    25400         3
# 1     35000         3
# 7     72000         6
# 12    59000         5

# %%
clf.predict(x_test)
# Out:
# array([38095.04609266, 28109.62834008, 38327.28510448, 35102.48969677,
#        20750.16149625, 25758.21502196])

# %%
y_test
# Out:
# 16    35500
# 6     32000
# 15    35000
# 1     34000
# 7     19300
# 12    26000
# Name: Sell Price($), dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.8230165988589051

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 10)
x_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 18    87600         8
